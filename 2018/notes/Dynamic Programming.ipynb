# %% [markdown]
# # Fibonacci Numbers

# %%
def fib(i):
    '''Calculate and return the ith
       Fibonacci number where i>=0'''
#     print("calling fib with input {}".format(i))
    if i<=2:       
        return 1 
    n = fib(i-1) + fib(i-2)
    return n

# %%
fib(6)
# Out:
# 8

# %%
for i in range(2,50,10):
    print(i, fib(i))
# Out:
# 2 1
# 12 144
# 22 17711
# 32 2178309
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-aa16f9435f00> in <module>()
#       1 for i in range(2,50,10):
# ----> 2     print(i, fib(i))
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# <ipython-input-11-08dbc7d3e8b3> in fib(i)
#       5     if i<=2:
#       6         return 1
# ----> 7     n = fib(i-1) + fib(i-2)
#       8     return n
#
# KeyboardInterrupt:

# %%
def fib(i, memo=None):
    '''Calculate and return the ith
       Fibonacci number where i>=0.
       Time complexity: Theta(i^2)
       Space complexity: Theta(i^2)
       Note that fib(i) needs i bits..
    '''
    if memo is None:
        memo = dict()
    if i in memo:
        return memo[i]
    if i<=1:
        memo[i] = i
        return i 
    n = fib(i-1, memo) + fib(i-2, memo)
    memo[i] = n
    return n

# %%
for i in range(2,200,10):
    print(i, fib(i))
# Out:
# 2 1
# 12 144
# 22 17711
# 32 2178309
# 42 267914296
# 52 32951280099
# 62 4052739537881
# 72 498454011879264
# 82 61305790721611591
# 92 7540113804746346429
# 102 927372692193078999176
# 112 114059301025943970552219
# 122 14028366653498915298923761
# 132 1725375039079340637797070384
# 142 212207101440105399533740733471
# 152 26099748102093884802012313146549
# 162 3210056809456107725247980776292056
# 172 394810887814999156320699623170776339
# 182 48558529144435440119720805669229197641
# 192 5972304273877744135569338397692020533504

# %%
fib(1000)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-16-ebfa76d57368> in <module>()
# ----> 1 fib(1000)
#
# <ipython-input-14-ddec7247ff27> in fib(i, memo)
#      13         memo[i] = i
#      14         return i
# ---> 15     n = fib(i-1, memo) + fib(i-2, memo)
#      16     memo[i] = n
#      17     return n
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-14-ddec7247ff27> in fib(i, memo)
#      13         memo[i] = i
#      14         return i
# ---> 15     n = fib(i-1, memo) + fib(i-2, memo)
#      16     memo[i] = n
#      17     return n
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
import sys
sys.setrecursionlimit(1500)

# %%
fib(1000)
# Out:
# 43466557686937456435688527675040625802564660517371780402481729089536555417949051890403879840079255169295922593080322634775209689623239873322471161642996440906533187938298969649928516003704476137795166849228875

# %% [markdown]
# # Knapsack

# %%
import sys
sys.setrecursionlimit(10000)

# %%
def knapsack(k, capacity):
    '''Calculates the maximum value that can be 
    achieved using the items 0...k
    whose values and sizes are in the identically
    named global variables (ouch!) while
    meeting the constraint that the total size
    of packed items <=capacity.'''
    # base case
    if k==0:
        ret = 0 if sizes[0] > capacity else values[0]
        return ret
    max_value = knapsack(k-1, capacity)
    if sizes[k] <= capacity: # we could pack item k
        packing_value = values[k] + knapsack(k-1, capacity-sizes[k])
        max_value = max( max_value, packing_value )
    return max_value

# %%
values = [5,10,2,4,5]
sizes  = [10,7,3,4,1]
knapsack(len(values)-1, 10)
# Out:
# 15

# %%
import random
l = 2000
values = [random.randrange(0,100) for i in range(l)]
sizes  = [random.randrange(0,100) for i in range(l)]

knapsack(len(values)-1, 10)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-21-12eea3e17db4> in <module>()
#       4 sizes  = [random.randrange(0,100) for i in range(l)]
#       5
# ----> 6 knapsack(len(values)-1, 10)
#
# <ipython-input-19-3af2e7f60e75> in knapsack(k, capacity)
#      10         ret = 0 if sizes[0] > capacity else values[0]
#      11         return ret
# ---> 12     max_value = knapsack(k-1, capacity)
#      13     if sizes[k] <= capacity: # we could pack item k
#      14         packing_value = values[k] + knapsack(k-1, capacity-sizes[k])
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-19-3af2e7f60e75> in knapsack(k, capacity)
#      10         ret = 0 if sizes[0] > capacity else values[0]
#      11         return ret
# ---> 12     max_value = knapsack(k-1, capacity)
#      13     if sizes[k] <= capacity: # we could pack item k
#      14         packing_value = values[k] + knapsack(k-1, capacity-sizes[k])
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
def knapsack(k, capacity, memo=None):
    '''Calculates the maximum value that can be 
    achieved using the items 0...k
    whose values and sizes are in the identically
    named global variables (ouch!) while
    meeting the constraint that the total size
    of packed items <=capacity.'''
    # base case
    if memo is None:
        memo = dict()
    if (k,capacity) in memo:
        return memo[(k,capacity)]
    if k==0:
        ret = 0 if sizes[0] > capacity else values[0]
        memo[(k,capacity)] = ret
        return ret
    max_value = knapsack(k-1, capacity, memo)
    if sizes[k] <= capacity: # we could pack item k
        packing_value = values[k] + knapsack(k-1, capacity-sizes[k], memo)
        max_value = max( max_value, packing_value )
    memo[(k,capacity)] = max_value
    return max_value

# %%
values = [5,10,2,4,5]
sizes  = [10,7,3,4,1]
knapsack(len(values)-1, 10)
# Out:
# 15

# %%
# Testing ideas:
# 1. Check against alternate brute force solution
# 2. Handcalculated
# 3. Check against potentially suboptimal algorithms
# 4. Go for edge cases
# 5. Check whether under different permutations of the input you get identical results

# %%
import random
l = 2000
values = [random.randrange(0,100) for i in range(l)]
sizes  = [random.randrange(0,100) for i in range(l)]

# %%
knapsack(len(values)-1, 10)
# Out:
# 1603
